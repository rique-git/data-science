# %% [markdown]
# # Data Analysis with Matplotlib

# %%
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
data = pd.read_csv("games_data.csv", index_col="datetime")

# %%
data.head()
# Out:
#                     game type champion played  team position    win    alied1  \
# datetime
# 2023-12-30 03:00:01   CLASSIC          Darius  blue   JUNGLE   True   Alistar
# 2023-12-30 02:22:41   CLASSIC           Poppy   red   JUNGLE   True  Malphite
# 2023-12-29 22:12:23   CLASSIC          Thresh   red  SUPPORT  False      Yone
# 2023-12-29 21:20:03   CLASSIC          Samira   red   BOTTOM  False    Singed
# 2023-12-29 19:56:01   CLASSIC           Briar  blue   JUNGLE   True     Quinn
#
#                       alied2  alied3       alied4     enemy1  ...      enemy5  \
# datetime                                                      ...
# 2023-12-30 03:00:01    Yasuo   Nilah  MissFortune       Kled  ...      Maokai
# 2023-12-30 02:22:41    Yasuo    Jinx       Velkoz      Garen  ...       Amumu
# 2023-12-29 22:12:23    Viego    Ahri       Ezreal  Gangplank  ...  Blitzcrank
# 2023-12-29 21:20:03    Briar    Yone      Morgana     Illaoi  ...        Nami
# 2023-12-29 19:56:01  Orianna  Lucian     Nautilus     Darius  ...        Shen
#
#                           alied1name       alied2name       alied3name  \
# datetime
# 2023-12-30 03:00:01       Elsword3Q1         Rafa3520        dxtraxion
# 2023-12-30 02:22:41  IGretaThunbergI         Rafa3520        LllEANllL
# 2023-12-29 22:12:23             H10K           Nixo81  midlane or feed
# 2023-12-29 21:20:03      Risikogamer  Y0uSHALLn0tPASS      SilenceBero
# 2023-12-29 19:56:01  MylittlePOKEman         Dimmytri      Stewart Big
#
#                            alied4name   enemy1name    enemy2name   enemy3name  \
# datetime
# 2023-12-30 03:00:01      Traumatismes     KlamDoom    Cornelygun        Sor4x
# 2023-12-30 02:22:41  König Spaßverein      WorldTC   SteelWizard   xxxalex161
# 2023-12-29 22:12:23          VicHeeZe          NaN        T0mib0    Loctalian
# 2023-12-29 21:20:03  SerpetteDeTonton  MSG Barbell    pauliebags  Mr deglaire
# 2023-12-29 19:56:01        Mastafista    Valkvísir  CEO of Xpeng    IsMa13lol
#
#                           enemy4name        enemy5name
# datetime
# 2023-12-30 03:00:01       Darragh565            Spoοky
# 2023-12-30 02:22:41    Asx Larv1Yelk          Torettte
# 2023-12-29 22:12:23       IronYeager         DonJesus7
# 2023-12-29 21:20:03            BK209  Debutantpasteque
# 2023-12-29 19:56:01  NapoleonDerPate        RevivedGod
#
# [5 rows x 23 columns]

# %% [markdown]
# # Variable Distributions

# %%
for col in ["game type", "champion played", "team", "position", "win"]:
    value_counts_result = data[col].value_counts()

    # Visualize the counts using a bar plot
    value_counts_result.plot(kind='bar', rot=60)
    plt.xlabel(col)
    plt.ylabel('Count')
    plt.title(f'Distribution of {col}')
    plt.show()

# %%
alied_champs = pd.Series()

columns_to_sum = ["alied1",'alied2', "alied3", "alied4"]

for column in columns_to_sum:
    new_alied = data[column].value_counts()
    alied_champs = alied_champs.add(new_alied, fill_value=0)


alied_champs = alied_champs.sort_values(ascending=False)


# Visualize the counts using a bar plot
plt.figure(figsize=(20, 6))
alied_champs.plot(kind='bar', rot=75)
plt.xlabel("alied champions")
plt.ylabel('Count')
plt.title(f'Distribution of alied champions')
plt.show()

# %%
alied_champs = alied_champs[alied_champs > 4]


# Visualize the counts using a bar plot
plt.figure(figsize=(10, 6))
alied_champs.plot(kind='bar', rot=60)
plt.xlabel("alied champions")
plt.ylabel('Count')
plt.title(f'Distribution of alied champions')
plt.show()

# %%
enemy_champs = pd.Series()

columns_to_sum = ["enemy1",'enemy2', "enemy3", "enemy4", "enemy5"]

for column in columns_to_sum:
    new_enemies = data[column].value_counts()
    enemy_champs = enemy_champs.add(new_enemies, fill_value=0)


enemy_champs = enemy_champs.sort_values(ascending=False)


# Visualize the counts using a bar plot
plt.figure(figsize=(25, 6))
enemy_champs.plot(kind='bar', rot=75)
plt.xlabel("enemy champions")
plt.ylabel('Count')
plt.title(f'Distribution of enemy champions')
plt.show()

# %%
enemy_champs = enemy_champs[enemy_champs > 4]


# Visualize the counts using a bar plot
plt.figure(figsize=(10, 6))
enemy_champs.plot(kind='bar', rot=60)
plt.xlabel("enemy champions")
plt.ylabel('Count')
plt.title(f'Distribution of enemy champions')
plt.show()

# %%
alied_summoners = pd.Series()

columns_to_sum = ["alied1name",'alied2name', "alied3name", "alied4name"]

for column in columns_to_sum:
    new_alied_name = data[column].value_counts()
    alied_summoners = alied_summoners.add(new_alied_name, fill_value=0)


alied_summoners = alied_summoners.sort_values(ascending=False)


# Visualize the counts using a bar plot
plt.figure(figsize=(20, 6))
alied_summoners.plot(kind='bar', rot=75)
plt.xlabel("alied champions")
plt.ylabel('Count')
plt.title(f'Distribution of alied summoners')
plt.show()

# %%
alied_summoners = alied_summoners[alied_summoners >= 2]


# Visualize the counts using a bar plot
plt.figure(figsize=(10, 6))
alied_summoners.plot(kind='bar', rot=60)
plt.xlabel("alied champions")
plt.ylabel('Count')
plt.title(f'Distribution of alied summoners')

# Add the values
for i, value in enumerate(alied_summoners):
    plt.text(i, value, str(int(value)), ha='center', va='bottom')

plt.show()

# %%
enemy_summoners = pd.Series()

columns_to_sum = ["enemy1name",'enemy2name', "enemy3name", "enemy4name"]

for column in columns_to_sum:
    new_enemy_name = data[column].value_counts()
    enemy_summoners = enemy_summoners.add(new_enemy_name, fill_value=0)


enemy_summoners = enemy_summoners.sort_values(ascending=False)


# Visualize the counts using a bar plot
plt.figure(figsize=(20, 6))
enemy_summoners.plot(kind='bar', rot=75)
plt.xlabel("enemy summoners")
plt.ylabel('Count')
plt.title(f'Distribution of enemy summoners')
plt.show()

# %%
enemy_summoners = enemy_summoners[enemy_summoners >= 2]


# Visualize the counts using a bar plot
plt.figure(figsize=(10, 6))
enemy_summoners.plot(kind='bar', rot=60)
plt.xlabel("enemy summoners")
plt.ylabel('Count')
plt.title(f'Distribution of enemy summoners')

# Add the values
for i, value in enumerate(enemy_summoners):
    plt.text(i, value, str(int(value)), ha='center', va='bottom')

plt.show()

# %% [markdown]
# # Win rates

# %%
win_ratio = round((data['win'].value_counts()[True] / data['win'].value_counts().sum()), 3) * 100
print("Global win rate =", win_ratio, "%")
# Out:
# Global win rate = 53.5 %

# %%
classic_data = data[data['game type'] == 'CLASSIC']
win_ratio_classic = round((classic_data['win'].value_counts()[True] / classic_data['win'].value_counts().sum()), 3) * 100
print("Classic win rate=", win_ratio_classic, "%")
# Out:
# Classic win rate= 50.7 %

# %%
aram_data = data[data['game type'] == 'ARAM']
win_ratio_aram = round((aram_data['win'].value_counts()[True] / aram_data['win'].value_counts().sum()), 3) * 100
print("ARAM win rate=", win_ratio_aram, "%")
# Out:
# ARAM win rate= 60.0 %

# %%
plt.figure(figsize=(3,4))

plt.bar(["Global win rate",'Win rate classic', 'Win rate ARAM'], [win_ratio, win_ratio_classic, win_ratio_aram])

# Add labels and title
plt.ylim(0, 100)
plt.xticks(rotation=20)
plt.xlabel('Game Type')
plt.ylabel('Win rate')
plt.title('Win rate by game type')

# Add the values
for i, value in enumerate([win_ratio, win_ratio_classic, win_ratio_aram]):
    plt.text(i, value + 2, str(round(value,1)), ha='center', va='bottom')

# Show the plot
plt.show()

# %% [markdown]
# # Win rates by champion in Summoners Rift

# %%
# Calculate win rate by champion
played_champions = classic_data['champion played'].value_counts() > 2
filtered_data = classic_data[classic_data['champion played'].isin(played_champions[played_champions].index)]
win_rate_by_champion = round(filtered_data.groupby('champion played')['win'].mean(),3) * 100  # Multiply by 100 to get percentage

win_rate_by_champion = win_rate_by_champion.sort_values(ascending=False)

if len(win_rate_by_champion.index) > 0:
    # Plot the win rate
    plt.figure(figsize=(len(win_rate_by_champion.index),4))
    plt.ylim(0, 100)
    plt.bar(win_rate_by_champion.index, win_rate_by_champion)
    plt.xlabel('Champion')
    plt.ylabel('Win Rate (%)')
    plt.title('WR by Champ Summoners Rift')
    plt.xticks(rotation=45)  # Rotate x-axis labels for better readability

    for i, value in enumerate(win_rate_by_champion):
        plt.text(i, value + 2, str(round(value,1)), ha='center', va='bottom')

    # Show the plot
    plt.show()
else:
    print("not enough games")

# %% [markdown]
# # Win rates by champion in ARAM

# %%
# Calculate win rate by champion
played_champions = aram_data['champion played'].value_counts() >= 2
filtered_data = aram_data[aram_data['champion played'].isin(played_champions[played_champions].index)]
win_rate_by_champion = round(filtered_data.groupby('champion played')['win'].mean(),3) * 100  # Multiply by 100 to get percentage

win_rate_by_champion = win_rate_by_champion.sort_values(ascending=False)

# Plot the win rate
if len(win_rate_by_champion.index) > 0:
    plt.figure(figsize=(len(win_rate_by_champion.index),4))
    plt.ylim(0, 110)
    plt.bar(win_rate_by_champion.index, win_rate_by_champion)
    plt.xlabel('Champion')
    plt.ylabel('Win Rate (%)')
    plt.title('WR by Champ ARAM')
    plt.xticks(rotation=45)  # Rotate x-axis labels for better readability

    for i, value in enumerate(win_rate_by_champion):
        plt.text(i, value+2, str(round(value,1)), ha='center', va='bottom')

    # Show the plot
    plt.show()
else:
    print("not enough games")

# %% [markdown]
# # Data Analysis with seaborn

# %%
import seaborn as sns

for i in ["game type", "champion played", "team", "position", "win"]:
    plt.figure(figsize=(12, 6)) 
    ax = sns.histplot(data=data, x=i) #kde = True
    plt.title(f'Histogram of {i}')
    ax.tick_params(axis='x', rotation=70)
    plt.show()

# %%
sns.set_palette("deep")

plt.figure(figsize=(10,6))

sns.barplot(x="position", y="win", data=data, hue ="position")
# Out:
# <Axes: xlabel='position', ylabel='win'>

# %%
sns.set_palette("deep")

plt.figure(figsize=(10,6))

sns.barplot(x="position", y="win", data=data, hue ="team", errorbar = None)
# Out:
# <Axes: xlabel='position', ylabel='win'>
