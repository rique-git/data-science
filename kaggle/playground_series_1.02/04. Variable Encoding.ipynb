# %% [markdown]
# # Playground Series 1.02 🦆

# %% [markdown]
# ## Imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Read Dataset

# %%
train = pd.read_csv("../data/train.csv", index_col=  "id")
test = pd.read_csv("../data/test.csv", index_col=  "id")
print(train.shape)
train.head()
# Out:
# (300000, 25)
#    cat0 cat1 cat2 cat3 cat4 cat5 cat6 cat7 cat8 cat9  ...     cont5     cont6  \
# id                                                    ...
# 1     A    B    A    A    B    D    A    E    C    I  ...  0.881122  0.421650
# 2     B    A    A    A    B    B    A    E    A    F  ...  0.440011  0.346230
# 3     A    A    A    C    B    D    A    B    C    N  ...  0.914155  0.369602
# 4     A    A    A    C    B    D    A    E    G    K  ...  0.934138  0.578930
# 6     A    B    A    A    B    B    A    E    C    F  ...  0.382600  0.705940
#
#        cont7     cont8     cont9    cont10    cont11    cont12    cont13  \
# id
# 1   0.741413  0.895799  0.802461  0.724417  0.701915  0.877618  0.719903
# 2   0.278495  0.593413  0.546056  0.613252  0.741289  0.326679  0.808464
# 3   0.832564  0.865620  0.825251  0.264104  0.695561  0.869133  0.828352
# 4   0.407313  0.868099  0.794402  0.494269  0.698125  0.809799  0.614766
# 6   0.325193  0.440967  0.462146  0.724447  0.683073  0.343457  0.297743
#
#       target
# id
# 1   6.994023
# 2   8.071256
# 3   5.760456
# 4   7.806457
# 6   6.868974
#
# [5 rows x 25 columns]

# %%
train.cat0.value_counts()
# Out:
# cat0
# A    281471
# B     18529
# Name: count, dtype: int64

# %% [markdown]
# ## Variable Encoding

# %%
def var_encoding(df):
    df = df.replace({
        "A": 0, "B": 1, "C": 2, "D": 3, "E": 4, "F": 5, "G": 6, "H": 7, "I": 8, "J": 9,
        "K": 10, "L": 11, "M": 12, "N": 13, "O": 14, "P": 15, "Q": 16, "R": 17, "S": 18,
        "T": 19, "U": 20, "V": 21, "W": 22, "X": 23, "Y": 24, "Z": 25})

    return df

train = var_encoding(train)
test = var_encoding(test)

# %% [markdown]
# ## Save dataset

# %%
train.head()
# Out:
#     cat0  cat1  cat2  cat3  cat4  cat5  cat6  cat7  cat8  cat9  ...     cont5  \
# id                                                              ...
# 1      0     1     0     0     1     3     0     4     2     8  ...  0.881122
# 2      1     0     0     0     1     1     0     4     0     5  ...  0.440011
# 3      0     0     0     2     1     3     0     1     2    13  ...  0.914155
# 4      0     0     0     2     1     3     0     4     6    10  ...  0.934138
# 6      0     1     0     0     1     1     0     4     2     5  ...  0.382600
#
#        cont6     cont7     cont8     cont9    cont10    cont11    cont12  \
# id
# 1   0.421650  0.741413  0.895799  0.802461  0.724417  0.701915  0.877618
# 2   0.346230  0.278495  0.593413  0.546056  0.613252  0.741289  0.326679
# 3   0.369602  0.832564  0.865620  0.825251  0.264104  0.695561  0.869133
# 4   0.578930  0.407313  0.868099  0.794402  0.494269  0.698125  0.809799
# 6   0.705940  0.325193  0.440967  0.462146  0.724447  0.683073  0.343457
#
#       cont13    target
# id
# 1   0.719903  6.994023
# 2   0.808464  8.071256
# 3   0.828352  5.760456
# 4   0.614766  7.806457
# 6   0.297743  6.868974
#
# [5 rows x 25 columns]

# %%
test.head()
# Out:
#     cat0  cat1  cat2  cat3  cat4  cat5  cat6  cat7  cat8  cat9  ...     cont4  \
# id                                                              ...
# 0      0     1     0     2     1     3     0     4     4     6  ...  0.701679
# 5      0     1     0     2     1     3     0     4     2    11  ...  0.277480
# 15     0     1     0     2     1     3     0     4     2     5  ...  0.279508
# 16     0     0     1     0     1     3     0     4     4     5  ...  0.479503
# 17     0     1     0     0     1     1     0     4     4     8  ...  0.757845
#
#        cont5     cont6     cont7     cont8     cont9    cont10    cont11  \
# id
# 0   0.595507  0.286912  0.279884  0.202234  0.242654  0.285147  0.264308
# 5   0.479552  0.397436  0.476742  0.857073  0.516393  0.562065  0.730542
# 15  0.676395  0.695284  0.253316  0.586934  0.548555  0.836193  0.759788
# 16  0.759875  0.240049  0.298074  0.442475  0.596746  0.414131  0.255382
# 17  0.210232  0.329851  0.616663  0.170475  0.263235  0.710961  0.224045
#
#       cont12    cont13
# id
# 0   0.653654  0.302448
# 5   0.318492  0.736251
# 15  0.333572  0.273905
# 16  0.589080  0.311625
# 17  0.285860  0.794931
#
# [5 rows x 24 columns]

# %%
train.to_csv("../data/04. Encoded_train.csv", index="id")
test.to_csv("../data/04. Encoded_test.csv", index="id")
