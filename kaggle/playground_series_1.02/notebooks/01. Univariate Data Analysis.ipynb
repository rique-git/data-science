# %% [markdown]
# # Playground Series 1.02 🦆

# %% [markdown]
# ## Imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Read Dataset

# %%
data = pd.read_csv("../data/train.csv", index_col=  "id")
print(data.shape)
data.head()
# Out:
# (300000, 25)
#    cat0 cat1 cat2 cat3 cat4 cat5 cat6 cat7 cat8 cat9  ...     cont5     cont6  \
# id                                                    ...
# 1     A    B    A    A    B    D    A    E    C    I  ...  0.881122  0.421650
# 2     B    A    A    A    B    B    A    E    A    F  ...  0.440011  0.346230
# 3     A    A    A    C    B    D    A    B    C    N  ...  0.914155  0.369602
# 4     A    A    A    C    B    D    A    E    G    K  ...  0.934138  0.578930
# 6     A    B    A    A    B    B    A    E    C    F  ...  0.382600  0.705940
#
#        cont7     cont8     cont9    cont10    cont11    cont12    cont13  \
# id
# 1   0.741413  0.895799  0.802461  0.724417  0.701915  0.877618  0.719903
# 2   0.278495  0.593413  0.546056  0.613252  0.741289  0.326679  0.808464
# 3   0.832564  0.865620  0.825251  0.264104  0.695561  0.869133  0.828352
# 4   0.407313  0.868099  0.794402  0.494269  0.698125  0.809799  0.614766
# 6   0.325193  0.440967  0.462146  0.724447  0.683073  0.343457  0.297743
#
#       target
# id
# 1   6.994023
# 2   8.071256
# 3   5.760456
# 4   7.806457
# 6   6.868974
#
# [5 rows x 25 columns]

# %%
data.dtypes
# Out:
# cat0       object
# cat1       object
# cat2       object
# cat3       object
# cat4       object
# cat5       object
# cat6       object
# cat7       object
# cat8       object
# cat9       object
# cont0     float64
# cont1     float64
# cont2     float64
# cont3     float64
# cont4     float64
# cont5     float64
# cont6     float64
# cont7     float64
# cont8     float64
# cont9     float64
# cont10    float64
# cont11    float64
# cont12    float64
# cont13    float64
# target    float64
# dtype: object

# %% [markdown]
# ## Univariate Data Analysis

# %%
ncols = 2

nrows = -(-len(data.columns) // ncols)
fig, axes = plt.subplots(nrows=nrows, ncols=ncols, figsize=(15, 5 * nrows))
axes = axes.flatten()

for i, variable in enumerate(data.columns):
    ax = axes[i]
    #bins = min([len(data[variable].value_counts()),15])
    sns.histplot(data = data, x = variable, ax=ax, kde=True)
    ax.set_title(variable, fontsize=16) 
    ax.set_xlabel(variable, fontsize=14) 
    ax.set_ylabel('Frequency', fontsize=14)

# Remove empty subplots
for j in range(i + 1, nrows * ncols):
    fig.delaxes(axes[j])

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 10
#       8 ax = axes[i]
#       9 #bins = min([len(data[variable].value_counts()),15])
# ---> 10 sns.histplot(data = data, x = variable, ax=ax, kde=True)
#      11 ax.set_title(variable, fontsize=16)
#      12 ax.set_xlabel(variable, fontsize=14)
#
# File ~/.local/lib/python3.10/site-packages/seaborn/distributions.py:1416, in histplot(data, x, y, hue, weights, stat, bins, binwidth, binrange, discrete, cumulative, common_bins, common_norm, multiple, element, fill, shrink, kde, kde_kws, line_kws, thresh, pthresh, pmax, cbar, cbar_ax, cbar_kws, palette, hue_order, hue_norm, color, log_scale, legend, ax, **kwargs)
#    1405 estimate_kws = dict(
#    1406     stat=stat,
#    1407     bins=bins,
#    (...)
#    1411     cumulative=cumulative,
#    1412 )
#    1414 if p.univariate:
# -> 1416     p.plot_univariate_histogram(
#    1417         multiple=multiple,
#    1418         element=element,
#    1419         fill=fill,
#    1420         shrink=shrink,
#    1421         common_norm=common_norm,
#    1422         common_bins=common_bins,
#    1423         kde=kde,
#    1424         kde_kws=kde_kws,
#    1425         color=color,
#    1426         legend=legend,
#    1427         estimate_kws=estimate_kws,
#    1428         line_kws=line_kws,
#    1429         **kwargs,
#    1430     )
#    1432 else:
#    1434     p.plot_bivariate_histogram(
#    1435         common_bins=common_bins,
#    1436         common_norm=common_norm,
#    (...)
#    1446         **kwargs,
#    1447     )
#
# File ~/.local/lib/python3.10/site-packages/seaborn/distributions.py:447, in _DistributionPlotter.plot_univariate_histogram(self, multiple, element, fill, common_norm, common_bins, shrink, kde, kde_kws, color, legend, line_kws, estimate_kws, **plot_kws)
#     445     kde_kws.setdefault("cut", 0)
#     446     kde_kws["cumulative"] = estimate_kws["cumulative"]
# --> 447     densities = self._compute_univariate_density(
#     448         self.data_variable,
#     449         common_norm,
#     450         common_bins,
#     451         kde_kws,
#     452         warn_singular=False,
#     453     )
#     455 # First pass through the data to compute the histograms
#     456 for sub_vars, sub_data in self.iter_data("hue", from_comp_data=True):
#     457
#     458     # Prepare the relevant data
#
# File ~/.local/lib/python3.10/site-packages/seaborn/distributions.py:345, in _DistributionPlotter._compute_univariate_density(self, data_variable, common_norm, common_grid, estimate_kws, warn_singular)
#     341 try:
#     342     if not singular:
#     343         # Convoluted approach needed because numerical failures
#     344         # can manifest in a few different ways.
# --> 345         density, support = estimator(observations, weights=weights)
#     346 except np.linalg.LinAlgError:
#     347     singular = True
#
# File ~/.local/lib/python3.10/site-packages/seaborn/_statistics.py:193, in KDE.__call__(self, x1, x2, weights)
#     191 """Fit and evaluate on univariate or bivariate data."""
#     192 if x2 is None:
# --> 193     return self._eval_univariate(x1, weights)
#     194 else:
#     195     return self._eval_bivariate(x1, x2, weights)
#
# File ~/.local/lib/python3.10/site-packages/seaborn/_statistics.py:162, in KDE._eval_univariate(self, x, weights)
#     158     density = np.array([
#     159         kde.integrate_box_1d(s_0, s_i) for s_i in support
#     160     ])
#     161 else:
# --> 162     density = kde(support)
#     164 return density, support
#
# File ~/.local/lib/python3.10/site-packages/scipy/stats/_kde.py:271, in gaussian_kde.evaluate(self, points)
#     268         raise ValueError(msg)
#     270 output_dtype, spec = _get_output_dtype(self.covariance, points)
# --> 271 result = gaussian_kernel_estimate[spec](
#     272     self.dataset.T, self.weights[:, None],
#     273     points.T, self.cho_cov, output_dtype)
#     275 return result[:, 0]
#
# KeyboardInterrupt:
